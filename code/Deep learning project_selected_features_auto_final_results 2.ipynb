# %% [markdown]
# We'll be using this library to implement the TCN: https://pypi.org/project/pytorch-tcn/1.0.0/ which is based on this paper: https://arxiv.org/abs/1803.01271

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import optuna
from torch.utils.data import DataLoader, Dataset, random_split
from sklearn.preprocessing import StandardScaler
from pytorch_tcn import TCN

# %%
# Define the file path
file_path = 'https://media.githubusercontent.com/media/iamj4ckie/shared-project-data/refs/heads/main/data/wind_speed_13_n.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

df.head()
# Out:
#            Mx1         Mx2          Mx3           My1          My2  \
# 0  5669.242169  588.682952 -2283.570120  12206.506791  6735.678178
# 1  6059.851372   77.800854 -2110.975042  11765.633220  7146.208774
# 2  5694.798598  614.439242 -2373.027775  12197.570281  6665.876391
# 3  5647.114990  493.144220 -2300.119212  11914.937535  7348.576783
# 4  5720.660260  467.386734 -2085.456805  11910.216305  6819.000947
#
#            My3        Mz1       Mz2        Mz3     Theta  ...       Vwy  \
# 0  9289.590353 -46.636673 -0.763518  57.837418  0.892055  ...  2.716019
# 1  8781.542941 -47.358326 -0.786074  58.079163  0.927567  ...  2.604409
# 2  8928.649687 -48.055740 -0.761416  58.283371  0.916719  ...  2.871704
# 3  8595.999193 -48.655266 -0.814706  58.498627  0.942775  ...  3.027272
# 4  8303.087862 -49.212616 -0.787967  58.749008  0.959359  ...  2.997196
#
#         Vwz     beta1     beta2     beta3    dbeta1    dbeta2    dbeta3  \
# 0  0.062275  0.056162  0.054724  0.054979  0.004734 -0.000343 -0.000591
# 1 -0.010360  0.056089  0.054646  0.054902  0.004317 -0.000806 -0.001110
# 2  0.164501  0.056617  0.055168  0.055424  0.003857 -0.001303 -0.001663
# 3  0.295967  0.056115  0.054658  0.054913  0.004329 -0.000818 -0.001232
# 4  0.168861  0.056623  0.055156  0.055411  0.003878 -0.001286 -0.001756
#
#      omega_r        t
# 0  12.056893  0.00000
# 1  12.064904  0.00625
# 2  12.064869  0.01250
# 3  12.056639  0.01875
# 4  12.047874  0.02500
#
# [5 rows x 21 columns]

# %%
# features = ['beta1', 'beta2', 'beta3', 'Theta', 'omega_r', 'Vwx']   # Mandatory input features
features = ['Mx1', 'Mx2', 'Mx3', 'My1', 'My2', 'My3', 'Theta', 'Vwx', 'beta1', 'beta2', 'beta3', 'omega_r']   # Our selected input features
# features = ['beta1', 'beta2', 'beta3', 'Theta', 'omega_r', 'Vwx', 'dbeta1', 'dbeta2', 'dbeta3', 'Mx1', 'Mx2', 'Mx3', 'My1', 'My2', 'My3', 'Vwy', 'Vwz']   # All input features

targets = ['Mz1', 'Mz2', 'Mz3']  # Output

# %%
X = df[features].values
y = df[targets].values

# %%
# Normalize features and targets
scaler = StandardScaler()
X = scaler.fit_transform(X)
scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
# Create PyTorch dataset so we can use DataLoader function for train and test set creation
class WindTurbineDataset(Dataset):

    def __init__(self, features, targets):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.targets = torch.tensor(targets, dtype=torch.float32)

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.targets[idx]

# %%
dataset = WindTurbineDataset(X, y)

# %%
# Set size for train, validation and test sets
train_size = int(0.7 * len(dataset))
test_size = len(dataset) - train_size

train_set, test_set = random_split(dataset, [train_size, test_size])

batch_size = 64

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, drop_last=False)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)

# %%
print("Training data")
print(f"Number of points: {len(train_set)}")
print("\nTest data")
print(f"Number of points: {len(test_set)}")
# Out:
# Training data
# Number of points: 224000
#
# Test data
# Number of points: 96001

# %%
class TCNModel(nn.Module):
    def __init__(self, input_size, output_size, num_channels, dropout):
        super(TCNModel, self).__init__()

        activation_fn = nn.ReLU()

        self.tcn = TCN(
            input_size,
            num_channels,
            dropout=dropout
        )

        # We need this layer to map the TCN ouput to the target size
        self.fc = nn.Linear(num_channels[-1], output_size)

    def forward(self, x):
        x = self.tcn(x)
        x = self.fc(x[:, :, -1])
        return x

input_size = len(features)
output_size = len(targets)
num_channels = [32, 64, 128]
dropout = 0.18

model = TCNModel(input_size, output_size, num_channels, dropout)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
print(model)
# Out:
# TCNModel(
#   (tcn): TCN(
#     (network): ModuleList(
#       (0): TemporalBlock(
#         (conv1): ParametrizedTemporalConv1d(
#           12, 32, kernel_size=(4,), stride=(1,)
#           (padder): ConstantPad1d(padding=(3, 0), value=0.0)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (conv2): ParametrizedTemporalConv1d(
#           32, 32, kernel_size=(4,), stride=(1,)
#           (padder): ConstantPad1d(padding=(3, 0), value=0.0)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (activation1): ReLU()
#         (activation2): ReLU()
#         (activation_final): ReLU()
#         (dropout1): Dropout(p=0.18, inplace=False)
#         (dropout2): Dropout(p=0.18, inplace=False)
#         (downsample): Conv1d(12, 32, kernel_size=(1,), stride=(1,))
#       )
#       (1): TemporalBlock(
#         (conv1): ParametrizedTemporalConv1d(
#           32, 64, kernel_size=(4,), stride=(1,), dilation=(2,)
#           (padder): ConstantPad1d(padding=(6, 0), value=0.0)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (conv2): ParametrizedTemporalConv1d(
#           64, 64, kernel_size=(4,), stride=(1,), dilation=(2,)
#           (padder): ConstantPad1d(padding=(6, 0), value=0.0)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (activation1): ReLU()
#         (activation2): ReLU()
#         (activation_final): ReLU()
#         (dropout1): Dropout(p=0.18, inplace=False)
#         (dropout2): Dropout(p=0.18, inplace=False)
#         (downsample): Conv1d(32, 64, kernel_size=(1,), stride=(1,))
#       )
#       (2): TemporalBlock(
#         (conv1): ParametrizedTemporalConv1d(
#           64, 128, kernel_size=(4,), stride=(1,), dilation=(4,)
#           (padder): ConstantPad1d(padding=(12, 0), value=0.0)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (conv2): ParametrizedTemporalConv1d(
#           128, 128, kernel_size=(4,), stride=(1,), dilation=(4,)
#           (padder): ConstantPad1d(padding=(12, 0), value=0.0)
#           (parametrizations): ModuleDict(
#             (weight): ParametrizationList(
#               (0): _WeightNorm()
#             )
#           )
#         )
#         (activation1): ReLU()
#         (activation2): ReLU()
#         (activation_final): ReLU()
#         (dropout1): Dropout(p=0.18, inplace=False)
#         (dropout2): Dropout(p=0.18, inplace=False)
#         (downsample): Conv1d(64, 128, kernel_size=(1,), stride=(1,))
#       )
#     )
#   )
#   (fc): Linear(in_features=128, out_features=3, bias=True)
# )

# %%
input_size = len(features)
output_size = len(targets)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the objective function
def objective(trial):
    learning_rate = trial.suggest_loguniform("learning_rate", 0.00009, 0.0001)
    dropout = trial.suggest_uniform("dropout", 0.2, 0.3)
    num_channels = trial.suggest_categorical("num_channels", [[32, 64, 64], [64, 128, 128], [32, 64, 128]])

    model = TCNModel(input_size, output_size, num_channels, dropout)
    model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    loss_fn = nn.MSELoss()

    best_val_loss = float('inf')
    patience_counter = 0
    max_epochs = 10
    patience = 3

    for epoch in range(max_epochs):
        model.train()
        for batch_features, batch_targets in train_loader:
            batch_features, batch_targets = batch_features.to(device), batch_targets.to(device)
            batch_features = batch_features.unsqueeze(2)

            predictions = model(batch_features).squeeze()
            loss = loss_fn(predictions, batch_targets)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for val_features, val_targets in test_loader:
                val_features, val_targets = val_features.to(device), val_targets.to(device)
                val_features = val_features.unsqueeze(2)
                val_predictions = model(val_features).squeeze()
                val_loss += loss_fn(val_predictions, val_targets).item()

        avg_val_loss = val_loss / len(test_loader)

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            break

    return best_val_loss

# Define and run the study
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=20)
# Out:
# [I 2024-12-21 00:50:55,377] A new study created in memory with name: no-name-77ad37a2-cb72-4f8e-a553-b41a4b677018
# C:\Users\ropet\AppData\Local\Temp\ipykernel_25772\1514738167.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.00009, 0.0001)
# C:\Users\ropet\AppData\Local\Temp\ipykernel_25772\1514738167.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout = trial.suggest_uniform("dropout", 0.2, 0.3)
# C:\Users\ropet\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [32, 64, 64] which is of type list.
#   warnings.warn(message)
# C:\Users\ropet\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [64, 128, 128] which is of type list.
#   warnings.warn(message)
# C:\Users\ropet\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [32, 64, 128] which is of type list.
#   warnings.warn(message)
# [I 2024-12-21 00:59:04,350] Trial 0 finished with value: 0.03187621070941289 and parameters: {'learning_rate': 9.192959438585131e-05, 'dropout': 0.2504179521005035, 'num_channels': [32, 64, 64]}. Best is trial 0 with value: 0.03187621070941289.
# C:\Users\ropet\AppData\Local\Temp\ipykernel_25772\1514738167.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 0.00009, 0.0001)
# C:\Users\ropet\AppData\Local\Temp\ipykernel_25772\1514738167.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout = trial.suggest_uniform("dropout", 0.2, 0.3)
# C:\Users\ropet\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [32, 64, 64] which is of type list.
#   warnings.warn(message)
# C:\Users\ropet\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [64, 128, 128] which is of type list.
#   warnings.warn(message)
# C:\Users\ropet\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\optuna\distributions.py:524: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains [32, 64, 128] which is of type list.
#   warnings.warn(message)
# [I 2024-12-21 01:07:17,119] Trial 1 finished with value: 0.031759039419392746 and parameters: {'learning_rate': 9.348241967318518e-05, 'dropout': 0.21112875591077349, 'num_channels': [32, 64, 64]}. Best is trial 1 with value: 0.031759039419392746.
# [I 2024-12-21 01:17:45,675] Trial 2 finished with value: 0.02837801571562886 and parameters: {'learning_rate': 9.595861213888033e-05, 'dropout': 0.2760925283612785, 'num_channels': [64, 128, 128]}. Best is trial 2 with value: 0.02837801571562886.
# [I 2024-12-21 01:27:41,261] Trial 3 finished with value: 0.027896149352192878 and parameters: {'learning_rate': 9.669664791001227e-05, 'dropout': 0.23519531265469762, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 01:36:33,279] Trial 4 finished with value: 0.03084487018113335 and parameters: {'learning_rate': 9.671622698826507e-05, 'dropout': 0.29945509375401036, 'num_channels': [32, 64, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 01:43:48,745] Trial 5 finished with value: 0.03251396102830768 and parameters: {'learning_rate': 9.110053515114108e-05, 'dropout': 0.2914691379748237, 'num_channels': [32, 64, 64]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 01:51:52,588] Trial 6 finished with value: 0.03221433064589898 and parameters: {'learning_rate': 9.043842983783791e-05, 'dropout': 0.25362582317928195, 'num_channels': [32, 64, 64]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 02:01:32,704] Trial 7 finished with value: 0.028588786005973817 and parameters: {'learning_rate': 9.814651121350505e-05, 'dropout': 0.2802597203868993, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 02:09:05,374] Trial 8 finished with value: 0.03247952464595437 and parameters: {'learning_rate': 9.208548435551647e-05, 'dropout': 0.2791428210022498, 'num_channels': [32, 64, 64]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 02:17:59,044] Trial 9 finished with value: 0.030470008617887893 and parameters: {'learning_rate': 9.105663172370044e-05, 'dropout': 0.20666448359597775, 'num_channels': [32, 64, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 02:27:54,656] Trial 10 finished with value: 0.028194824558993182 and parameters: {'learning_rate': 9.990518764652123e-05, 'dropout': 0.22571455526298295, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 02:37:44,596] Trial 11 finished with value: 0.027905682494242984 and parameters: {'learning_rate': 9.908089406376368e-05, 'dropout': 0.22843278517748533, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 02:47:36,396] Trial 12 finished with value: 0.028283668361604213 and parameters: {'learning_rate': 9.87746717262462e-05, 'dropout': 0.23911632968917718, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 02:57:26,194] Trial 13 finished with value: 0.028160740048935016 and parameters: {'learning_rate': 9.706034611469398e-05, 'dropout': 0.2260096732299692, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 03:07:14,779] Trial 14 finished with value: 0.028124540947377683 and parameters: {'learning_rate': 9.457073170743958e-05, 'dropout': 0.23508521580099337, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 03:16:57,652] Trial 15 finished with value: 0.028055806099126737 and parameters: {'learning_rate': 9.840194215138829e-05, 'dropout': 0.2616978965694977, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 03:26:53,790] Trial 16 finished with value: 0.028104588175813357 and parameters: {'learning_rate': 9.523784703540918e-05, 'dropout': 0.22160817500235597, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 03:35:49,144] Trial 17 finished with value: 0.03036859750871857 and parameters: {'learning_rate': 9.991226804881448e-05, 'dropout': 0.2370863840209009, 'num_channels': [32, 64, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 03:45:44,797] Trial 18 finished with value: 0.028660052238653103 and parameters: {'learning_rate': 9.698481752248784e-05, 'dropout': 0.2626604100976072, 'num_channels': [64, 128, 128]}. Best is trial 3 with value: 0.027896149352192878.
# [I 2024-12-21 03:55:30,726] Trial 19 finished with value: 0.027622225229938825 and parameters: {'learning_rate': 9.382907895939157e-05, 'dropout': 0.2195300017232711, 'num_channels': [64, 128, 128]}. Best is trial 19 with value: 0.027622225229938825.

# %%
learning_rate = 0.001

loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
num_epochs = 300
#validation_every_steps = 100
validation_every_steps = len(train_loader) // 10

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

train_losses = []
val_losses = []
epoch_train_losses = []
epoch_val_losses = []

# For early stopping
best_val_loss = float('inf')
patience = 300
patience_counter = 0


# Training loop
step = 0
batch_train_loss = 0

for epoch in range(num_epochs):
    model.train()
    epoch_train_loss = 0

    print(f"Epoch {epoch+1}/{num_epochs}")
    for batch_features, batch_targets in train_loader:
        batch_features, batch_targets = batch_features.to(device), batch_targets.to(device)

        batch_features = batch_features.unsqueeze(2)

        # Forward pass
        predictions = model(batch_features).squeeze()
        loss = loss_fn(predictions, batch_targets)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        batch_train_loss += loss.item()
        epoch_train_loss += loss.item()
        step += 1

        if step % validation_every_steps == 0:
            avg_train_loss = batch_train_loss / validation_every_steps
            train_losses.append(avg_train_loss)
            batch_train_loss = 0

            model.eval()
            with torch.no_grad():
                val_loss = 0
                for val_features, val_targets in test_loader:
                    val_features, val_targets = val_features.to(device), val_targets.to(device)
                    val_features = val_features.unsqueeze(2)
                    val_predictions = model(val_features).squeeze()
                    val_loss += loss_fn(val_predictions, val_targets).item()

            avg_val_loss = val_loss / len(test_loader)
            val_losses.append(avg_val_loss)
            print(f"Step {step}: Training Loss = {avg_train_loss:.4f}, Validation Loss = {avg_val_loss:.4f}")
            model.train()

    remaining_steps = step % validation_every_steps or validation_every_steps
    if batch_train_loss > 0:
        avg_train_loss = batch_train_loss / remaining_steps
        train_losses.append(avg_train_loss)
        batch_train_loss = 0

    avg_train_loss = epoch_train_loss / len(train_loader)
    epoch_train_losses.append(avg_train_loss)
    print(f"Epoch {epoch+1}: Training Loss = {avg_train_loss:.4f}")

    model.eval()
    with torch.no_grad():
        val_loss = 0
        for val_features, val_targets in test_loader:
            val_features, val_targets = val_features.to(device), val_targets.to(device)
            val_features = val_features.unsqueeze(2)
            val_predictions = model(val_features).squeeze()
            val_loss += loss_fn(val_predictions, val_targets).item()

    avg_val_loss = val_loss / len(test_loader)
    epoch_val_losses.append(avg_val_loss)
    print(f"Epoch {epoch+1}: Validation Loss = {avg_val_loss:.4f}")

    # Early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        patience_counter = 0
        torch.save(model.state_dict(), 'best_model.pth')  # Save best model
        print(f"New best validation loss: {best_val_loss:.4f}. Model saved.")
    else:
        patience_counter += 1
        print(f"No improvement in validation loss for {patience_counter} epoch(s).")
        if patience_counter >= patience:
            print("Early stopping triggered. Training stopped.")
            break

    model.train()

print("Training complete!")
# Out:
# Epoch 1/300
# Step 350: Training Loss = 0.1005, Validation Loss = 0.0431
# Step 700: Training Loss = 0.0436, Validation Loss = 0.0405
# Step 1050: Training Loss = 0.0403, Validation Loss = 0.0389
# Step 1400: Training Loss = 0.0388, Validation Loss = 0.0377
# Step 1750: Training Loss = 0.0377, Validation Loss = 0.0361
# Step 2100: Training Loss = 0.0371, Validation Loss = 0.0364
# Step 2450: Training Loss = 0.0370, Validation Loss = 0.0352
# Step 2800: Training Loss = 0.0361, Validation Loss = 0.0349
# Step 3150: Training Loss = 0.0357, Validation Loss = 0.0365
# Step 3500: Training Loss = 0.0353, Validation Loss = 0.0347
# Epoch 1: Training Loss = 0.0442
# Epoch 1: Validation Loss = 0.0347
# New best validation loss: 0.0347. Model saved.
# Epoch 2/300
# Step 3850: Training Loss = 0.0350, Validation Loss = 0.0366
# Step 4200: Training Loss = 0.0347, Validation Loss = 0.0343
# Step 4550: Training Loss = 0.0347, Validation Loss = 0.0349
# Step 4900: Training Loss = 0.0342, Validation Loss = 0.0330
# Step 5250: Training Loss = 0.0342, Validation Loss = 0.0337
# Step 5600: Training Loss = 0.0343, Validation Loss = 0.0334
# Step 5950: Training Loss = 0.0336, Validation Loss = 0.0335
# Step 6300: Training Loss = 0.0335, Validation Loss = 0.0340
# Step 6650: Training Loss = 0.0337, Validation Loss = 0.0340
# Step 7000: Training Loss = 0.0335, Validation Loss = 0.0329
# Epoch 2: Training Loss = 0.0341
# Epoch 2: Validation Loss = 0.0329
# New best validation loss: 0.0329. Model saved.
# Epoch 3/300
# Step 7350: Training Loss = 0.0329, Validation Loss = 0.0355
# Step 7700: Training Loss = 0.0329, Validation Loss = 0.0328
# Step 8050: Training Loss = 0.0326, Validation Loss = 0.0330
# Step 8400: Training Loss = 0.0327, Validation Loss = 0.0322
# Step 8750: Training Loss = 0.0328, Validation Loss = 0.0322
# Step 9100: Training Loss = 0.0326, Validation Loss = 0.0325
# Step 9450: Training Loss = 0.0320, Validation Loss = 0.0319
# Step 9800: Training Loss = 0.0322, Validation Loss = 0.0314
# Step 10150: Training Loss = 0.0319, Validation Loss = 0.0308
# Step 10500: Training Loss = 0.0322, Validation Loss = 0.0312
# Epoch 3: Training Loss = 0.0325
# Epoch 3: Validation Loss = 0.0312
# New best validation loss: 0.0312. Model saved.
# Epoch 4/300
# Step 10850: Training Loss = 0.0313, Validation Loss = 0.0308
# Step 11200: Training Loss = 0.0321, Validation Loss = 0.0313
# Step 11550: Training Loss = 0.0315, Validation Loss = 0.0308
# Step 11900: Training Loss = 0.0313, Validation Loss = 0.0311
# Step 12250: Training Loss = 0.0313, Validation Loss = 0.0305
# Step 12600: Training Loss = 0.0314, Validation Loss = 0.0304
# Step 12950: Training Loss = 0.0311, Validation Loss = 0.0306
# Step 13300: Training Loss = 0.0309, Validation Loss = 0.0307
# Step 13650: Training Loss = 0.0309, Validation Loss = 0.0308
# Step 14000: Training Loss = 0.0310, Validation Loss = 0.0303
# Epoch 4: Training Loss = 0.0313
# Epoch 4: Validation Loss = 0.0303
# New best validation loss: 0.0303. Model saved.
# Epoch 5/300
# Step 14350: Training Loss = 0.0304, Validation Loss = 0.0320
# Step 14700: Training Loss = 0.0301, Validation Loss = 0.0297
# Step 15050: Training Loss = 0.0304, Validation Loss = 0.0306
# Step 15400: Training Loss = 0.0302, Validation Loss = 0.0298
# Step 15750: Training Loss = 0.0306, Validation Loss = 0.0308
# Step 16100: Training Loss = 0.0304, Validation Loss = 0.0297
# Step 16450: Training Loss = 0.0303, Validation Loss = 0.0305
# Step 16800: Training Loss = 0.0302, Validation Loss = 0.0303
# Step 17150: Training Loss = 0.0302, Validation Loss = 0.0296
# Step 17500: Training Loss = 0.0299, Validation Loss = 0.0290
# Epoch 5: Training Loss = 0.0303
# Epoch 5: Validation Loss = 0.0290
# New best validation loss: 0.0290. Model saved.
# Epoch 6/300
# Step 17850: Training Loss = 0.0294, Validation Loss = 0.0292
# Step 18200: Training Loss = 0.0295, Validation Loss = 0.0291
# Step 18550: Training Loss = 0.0297, Validation Loss = 0.0290
# Step 18900: Training Loss = 0.0295, Validation Loss = 0.0287
# Step 19250: Training Loss = 0.0296, Validation Loss = 0.0294
# Step 19600: Training Loss = 0.0295, Validation Loss = 0.0293
# Step 19950: Training Loss = 0.0290, Validation Loss = 0.0288
# Step 20300: Training Loss = 0.0297, Validation Loss = 0.0292
# Step 20650: Training Loss = 0.0291, Validation Loss = 0.0289
# Step 21000: Training Loss = 0.0296, Validation Loss = 0.0284
# Epoch 6: Training Loss = 0.0295
# Epoch 6: Validation Loss = 0.0284
# New best validation loss: 0.0284. Model saved.
# Epoch 7/300
# Step 21350: Training Loss = 0.0291, Validation Loss = 0.0284
# Step 21700: Training Loss = 0.0292, Validation Loss = 0.0293
# Step 22050: Training Loss = 0.0287, Validation Loss = 0.0293
# Step 22400: Training Loss = 0.0285, Validation Loss = 0.0287
# Step 22750: Training Loss = 0.0286, Validation Loss = 0.0285
# Step 23100: Training Loss = 0.0283, Validation Loss = 0.0285
# Step 23450: Training Loss = 0.0287, Validation Loss = 0.0291
# Step 23800: Training Loss = 0.0287, Validation Loss = 0.0280
# Step 24150: Training Loss = 0.0288, Validation Loss = 0.0288
# Step 24500: Training Loss = 0.0287, Validation Loss = 0.0279
# Epoch 7: Training Loss = 0.0287
# Epoch 7: Validation Loss = 0.0279
# New best validation loss: 0.0279. Model saved.
# Epoch 8/300
# Step 24850: Training Loss = 0.0281, Validation Loss = 0.0284
# Step 25200: Training Loss = 0.0285, Validation Loss = 0.0285
# Step 25550: Training Loss = 0.0278, Validation Loss = 0.0275
# Step 25900: Training Loss = 0.0277, Validation Loss = 0.0274
# Step 26250: Training Loss = 0.0283, Validation Loss = 0.0277
# Step 26600: Training Loss = 0.0284, Validation Loss = 0.0275
# Step 26950: Training Loss = 0.0281, Validation Loss = 0.0279
# Step 27300: Training Loss = 0.0280, Validation Loss = 0.0272
# Step 27650: Training Loss = 0.0280, Validation Loss = 0.0287
# Step 28000: Training Loss = 0.0281, Validation Loss = 0.0280
# Epoch 8: Training Loss = 0.0281
# Epoch 8: Validation Loss = 0.0280
# No improvement in validation loss for 1 epoch(s).
# Epoch 9/300
# Step 28350: Training Loss = 0.0277, Validation Loss = 0.0269
# Step 28700: Training Loss = 0.0277, Validation Loss = 0.0270
# Step 29050: Training Loss = 0.0277, Validation Loss = 0.0269
# Step 29400: Training Loss = 0.0273, Validation Loss = 0.0272
# Step 29750: Training Loss = 0.0273, Validation Loss = 0.0270
# Step 30100: Training Loss = 0.0278, Validation Loss = 0.0278
# Step 30450: Training Loss = 0.0276, Validation Loss = 0.0272
# Step 30800: Training Loss = 0.0272, Validation Loss = 0.0271
# Step 31150: Training Loss = 0.0275, Validation Loss = 0.0264
# Step 31500: Training Loss = 0.0280, Validation Loss = 0.0271
# Epoch 9: Training Loss = 0.0276
# Epoch 9: Validation Loss = 0.0271
# New best validation loss: 0.0271. Model saved.
# Epoch 10/300
# Step 31850: Training Loss = 0.0269, Validation Loss = 0.0265
# Step 32200: Training Loss = 0.0271, Validation Loss = 0.0271
# Step 32550: Training Loss = 0.0269, Validation Loss = 0.0264
# Step 32900: Training Loss = 0.0273, Validation Loss = 0.0280
# Step 33250: Training Loss = 0.0275, Validation Loss = 0.0279
# Step 33600: Training Loss = 0.0271, Validation Loss = 0.0267
# Step 33950: Training Loss = 0.0271, Validation Loss = 0.0264
# Step 34300: Training Loss = 0.0271, Validation Loss = 0.0270
# Step 34650: Training Loss = 0.0269, Validation Loss = 0.0268
# Step 35000: Training Loss = 0.0271, Validation Loss = 0.0259
# Epoch 10: Training Loss = 0.0271
# Epoch 10: Validation Loss = 0.0259
# New best validation loss: 0.0259. Model saved.
# Epoch 11/300
# Step 35350: Training Loss = 0.0267, Validation Loss = 0.0268
# Step 35700: Training Loss = 0.0269, Validation Loss = 0.0266
# Step 36050: Training Loss = 0.0269, Validation Loss = 0.0264
# Step 36400: Training Loss = 0.0264, Validation Loss = 0.0265
# Step 36750: Training Loss = 0.0268, Validation Loss = 0.0270
# Step 37100: Training Loss = 0.0268, Validation Loss = 0.0260
# Step 37450: Training Loss = 0.0266, Validation Loss = 0.0257
# Step 37800: Training Loss = 0.0267, Validation Loss = 0.0265
# Step 38150: Training Loss = 0.0264, Validation Loss = 0.0256
# Step 38500: Training Loss = 0.0265, Validation Loss = 0.0257
# Epoch 11: Training Loss = 0.0267
# Epoch 11: Validation Loss = 0.0257
# New best validation loss: 0.0257. Model saved.
# Epoch 12/300
# Step 38850: Training Loss = 0.0261, Validation Loss = 0.0261
# Step 39200: Training Loss = 0.0262, Validation Loss = 0.0256
# Step 39550: Training Loss = 0.0262, Validation Loss = 0.0259
# Step 39900: Training Loss = 0.0261, Validation Loss = 0.0254
# Step 40250: Training Loss = 0.0267, Validation Loss = 0.0257
# Step 40600: Training Loss = 0.0263, Validation Loss = 0.0250
# Step 40950: Training Loss = 0.0262, Validation Loss = 0.0259
# Step 41300: Training Loss = 0.0264, Validation Loss = 0.0265
# Step 41650: Training Loss = 0.0263, Validation Loss = 0.0256
# Step 42000: Training Loss = 0.0261, Validation Loss = 0.0257
# Epoch 12: Training Loss = 0.0263
# Epoch 12: Validation Loss = 0.0257
# New best validation loss: 0.0257. Model saved.
# Epoch 13/300
# Step 42350: Training Loss = 0.0256, Validation Loss = 0.0252
# Step 42700: Training Loss = 0.0262, Validation Loss = 0.0251
# Step 43050: Training Loss = 0.0259, Validation Loss = 0.0253
# Step 43400: Training Loss = 0.0261, Validation Loss = 0.0252
# Step 43750: Training Loss = 0.0258, Validation Loss = 0.0260
# Step 44100: Training Loss = 0.0259, Validation Loss = 0.0256
# Step 44450: Training Loss = 0.0264, Validation Loss = 0.0250
# Step 44800: Training Loss = 0.0260, Validation Loss = 0.0256
# Step 45150: Training Loss = 0.0260, Validation Loss = 0.0255
# Step 45500: Training Loss = 0.0257, Validation Loss = 0.0250
# Epoch 13: Training Loss = 0.0260
# Epoch 13: Validation Loss = 0.0250
# New best validation loss: 0.0250. Model saved.
# Epoch 14/300
# Step 45850: Training Loss = 0.0255, Validation Loss = 0.0250
# Step 46200: Training Loss = 0.0257, Validation Loss = 0.0253
# Step 46550: Training Loss = 0.0256, Validation Loss = 0.0246
# Step 46900: Training Loss = 0.0259, Validation Loss = 0.0249
# Step 47250: Training Loss = 0.0256, Validation Loss = 0.0249
# Step 47600: Training Loss = 0.0255, Validation Loss = 0.0248
# Step 47950: Training Loss = 0.0256, Validation Loss = 0.0255
# Step 48300: Training Loss = 0.0254, Validation Loss = 0.0250
# Step 48650: Training Loss = 0.0255, Validation Loss = 0.0246
# Step 49000: Training Loss = 0.0256, Validation Loss = 0.0248
# Epoch 14: Training Loss = 0.0256
# Epoch 14: Validation Loss = 0.0248
# New best validation loss: 0.0248. Model saved.
# Epoch 15/300
# Step 49350: Training Loss = 0.0253, Validation Loss = 0.0254
# Step 49700: Training Loss = 0.0250, Validation Loss = 0.0248
# Step 50050: Training Loss = 0.0254, Validation Loss = 0.0244
# Step 50400: Training Loss = 0.0251, Validation Loss = 0.0254
# Step 50750: Training Loss = 0.0253, Validation Loss = 0.0246
# Step 51100: Training Loss = 0.0255, Validation Loss = 0.0243
# Step 51450: Training Loss = 0.0255, Validation Loss = 0.0247
# Step 51800: Training Loss = 0.0254, Validation Loss = 0.0253
# Step 52150: Training Loss = 0.0252, Validation Loss = 0.0247
# Step 52500: Training Loss = 0.0254, Validation Loss = 0.0245
# Epoch 15: Training Loss = 0.0253
# Epoch 15: Validation Loss = 0.0245
# New best validation loss: 0.0245. Model saved.
# Epoch 16/300
# Step 52850: Training Loss = 0.0250, Validation Loss = 0.0252
# Step 53200: Training Loss = 0.0255, Validation Loss = 0.0242
# Step 53550: Training Loss = 0.0250, Validation Loss = 0.0239
# Step 53900: Training Loss = 0.0247, Validation Loss = 0.0256
# Step 54250: Training Loss = 0.0254, Validation Loss = 0.0251
# Step 54600: Training Loss = 0.0251, Validation Loss = 0.0253
# Step 54950: Training Loss = 0.0253, Validation Loss = 0.0240
# Step 55300: Training Loss = 0.0249, Validation Loss = 0.0242
# Step 55650: Training Loss = 0.0250, Validation Loss = 0.0241
# Step 56000: Training Loss = 0.0249, Validation Loss = 0.0242
# Epoch 16: Training Loss = 0.0251
# Epoch 16: Validation Loss = 0.0242
# New best validation loss: 0.0242. Model saved.
# Epoch 17/300
# Step 56350: Training Loss = 0.0248, Validation Loss = 0.0241
# Step 56700: Training Loss = 0.0247, Validation Loss = 0.0253
# Step 57050: Training Loss = 0.0248, Validation Loss = 0.0244
# Step 57400: Training Loss = 0.0248, Validation Loss = 0.0237
# Step 57750: Training Loss = 0.0246, Validation Loss = 0.0240
# Step 58100: Training Loss = 0.0249, Validation Loss = 0.0239
# Step 58450: Training Loss = 0.0247, Validation Loss = 0.0246
# Step 58800: Training Loss = 0.0250, Validation Loss = 0.0243
# Step 59150: Training Loss = 0.0252, Validation Loss = 0.0237
# Step 59500: Training Loss = 0.0246, Validation Loss = 0.0243
# Epoch 17: Training Loss = 0.0248
# Epoch 17: Validation Loss = 0.0243
# No improvement in validation loss for 1 epoch(s).
# Epoch 18/300
# Step 59850: Training Loss = 0.0244, Validation Loss = 0.0243
# Step 60200: Training Loss = 0.0246, Validation Loss = 0.0252
# Step 60550: Training Loss = 0.0247, Validation Loss = 0.0248
# Step 60900: Training Loss = 0.0247, Validation Loss = 0.0237
# Step 61250: Training Loss = 0.0246, Validation Loss = 0.0241
# Step 61600: Training Loss = 0.0244, Validation Loss = 0.0236
# Step 61950: Training Loss = 0.0246, Validation Loss = 0.0237
# Step 62300: Training Loss = 0.0247, Validation Loss = 0.0232
# Step 62650: Training Loss = 0.0247, Validation Loss = 0.0236
# Step 63000: Training Loss = 0.0244, Validation Loss = 0.0236
# Epoch 18: Training Loss = 0.0246
# Epoch 18: Validation Loss = 0.0236
# New best validation loss: 0.0236. Model saved.
# Epoch 19/300
# Step 63350: Training Loss = 0.0243, Validation Loss = 0.0235
# Step 63700: Training Loss = 0.0246, Validation Loss = 0.0244
# Step 64050: Training Loss = 0.0244, Validation Loss = 0.0247
# Step 64400: Training Loss = 0.0241, Validation Loss = 0.0243
# Step 64750: Training Loss = 0.0244, Validation Loss = 0.0244
# Step 65100: Training Loss = 0.0243, Validation Loss = 0.0243
# Step 65450: Training Loss = 0.0243, Validation Loss = 0.0229
# Step 65800: Training Loss = 0.0246, Validation Loss = 0.0233
# Step 66150: Training Loss = 0.0242, Validation Loss = 0.0237
# Step 66500: Training Loss = 0.0242, Validation Loss = 0.0244
# Epoch 19: Training Loss = 0.0243
# Epoch 19: Validation Loss = 0.0244
# No improvement in validation loss for 1 epoch(s).
# Epoch 20/300
# Step 66850: Training Loss = 0.0242, Validation Loss = 0.0230
# Step 67200: Training Loss = 0.0245, Validation Loss = 0.0236
# Step 67550: Training Loss = 0.0244, Validation Loss = 0.0246
# Step 67900: Training Loss = 0.0243, Validation Loss = 0.0227
# Step 68250: Training Loss = 0.0239, Validation Loss = 0.0232
# Step 68600: Training Loss = 0.0243, Validation Loss = 0.0234
# Step 68950: Training Loss = 0.0241, Validation Loss = 0.0240
# Step 69300: Training Loss = 0.0239, Validation Loss = 0.0238
# Step 69650: Training Loss = 0.0240, Validation Loss = 0.0231
# Step 70000: Training Loss = 0.0243, Validation Loss = 0.0232
# Epoch 20: Training Loss = 0.0242
# Epoch 20: Validation Loss = 0.0232
# New best validation loss: 0.0232. Model saved.
# Epoch 21/300
# Step 70350: Training Loss = 0.0238, Validation Loss = 0.0231
# Step 70700: Training Loss = 0.0241, Validation Loss = 0.0238
# Step 71050: Training Loss = 0.0242, Validation Loss = 0.0239
# Step 71400: Training Loss = 0.0244, Validation Loss = 0.0228
# Step 71750: Training Loss = 0.0238, Validation Loss = 0.0231
# Step 72100: Training Loss = 0.0242, Validation Loss = 0.0232
# Step 72450: Training Loss = 0.0240, Validation Loss = 0.0234
# Step 72800: Training Loss = 0.0240, Validation Loss = 0.0231
# Step 73150: Training Loss = 0.0242, Validation Loss = 0.0250
# Step 73500: Training Loss = 0.0237, Validation Loss = 0.0234
# Epoch 21: Training Loss = 0.0240
# Epoch 21: Validation Loss = 0.0234
# No improvement in validation loss for 1 epoch(s).
# Epoch 22/300
# Step 73850: Training Loss = 0.0236, Validation Loss = 0.0234
# Step 74200: Training Loss = 0.0239, Validation Loss = 0.0232
# Step 74550: Training Loss = 0.0236, Validation Loss = 0.0231
# Step 74900: Training Loss = 0.0242, Validation Loss = 0.0231
# Step 75250: Training Loss = 0.0236, Validation Loss = 0.0227
# Step 75600: Training Loss = 0.0238, Validation Loss = 0.0236
# Step 75950: Training Loss = 0.0241, Validation Loss = 0.0232
# Step 76300: Training Loss = 0.0239, Validation Loss = 0.0230
# Step 76650: Training Loss = 0.0238, Validation Loss = 0.0232
# Step 77000: Training Loss = 0.0240, Validation Loss = 0.0229
# Epoch 22: Training Loss = 0.0238
# Epoch 22: Validation Loss = 0.0229
# New best validation loss: 0.0229. Model saved.
# Epoch 23/300
# Step 77350: Training Loss = 0.0236, Validation Loss = 0.0233
# Step 77700: Training Loss = 0.0234, Validation Loss = 0.0234
# Step 78050: Training Loss = 0.0236, Validation Loss = 0.0229
# Step 78400: Training Loss = 0.0235, Validation Loss = 0.0233
# Step 78750: Training Loss = 0.0236, Validation Loss = 0.0231
# Step 79100: Training Loss = 0.0238, Validation Loss = 0.0226
# Step 79450: Training Loss = 0.0234, Validation Loss = 0.0231
# Step 79800: Training Loss = 0.0237, Validation Loss = 0.0227
# Step 80150: Training Loss = 0.0237, Validation Loss = 0.0225
# Step 80500: Training Loss = 0.0239, Validation Loss = 0.0223
# Epoch 23: Training Loss = 0.0236
# Epoch 23: Validation Loss = 0.0223
# New best validation loss: 0.0223. Model saved.
# Epoch 24/300
# Step 80850: Training Loss = 0.0235, Validation Loss = 0.0227
# Step 81200: Training Loss = 0.0237, Validation Loss = 0.0225
# Step 81550: Training Loss = 0.0233, Validation Loss = 0.0223
# Step 81900: Training Loss = 0.0235, Validation Loss = 0.0224
# Step 82250: Training Loss = 0.0234, Validation Loss = 0.0229
# Step 82600: Training Loss = 0.0234, Validation Loss = 0.0225
# Step 82950: Training Loss = 0.0235, Validation Loss = 0.0225
# Step 83300: Training Loss = 0.0236, Validation Loss = 0.0226
# Step 83650: Training Loss = 0.0237, Validation Loss = 0.0229
# Step 84000: Training Loss = 0.0234, Validation Loss = 0.0233
# Epoch 24: Training Loss = 0.0235
# Epoch 24: Validation Loss = 0.0233
# No improvement in validation loss for 1 epoch(s).
# Epoch 25/300
# Step 84350: Training Loss = 0.0234, Validation Loss = 0.0224
# Step 84700: Training Loss = 0.0235, Validation Loss = 0.0222
# Step 85050: Training Loss = 0.0234, Validation Loss = 0.0229
# Step 85400: Training Loss = 0.0235, Validation Loss = 0.0225
# Step 85750: Training Loss = 0.0234, Validation Loss = 0.0224
# Step 86100: Training Loss = 0.0233, Validation Loss = 0.0223
# Step 86450: Training Loss = 0.0233, Validation Loss = 0.0225
# Step 86800: Training Loss = 0.0232, Validation Loss = 0.0224
# Step 87150: Training Loss = 0.0232, Validation Loss = 0.0222
# Step 87500: Training Loss = 0.0232, Validation Loss = 0.0233
# Epoch 25: Training Loss = 0.0233
# Epoch 25: Validation Loss = 0.0233
# No improvement in validation loss for 2 epoch(s).
# Epoch 26/300
# Step 87850: Training Loss = 0.0230, Validation Loss = 0.0238
# Step 88200: Training Loss = 0.0235, Validation Loss = 0.0225
# Step 88550: Training Loss = 0.0232, Validation Loss = 0.0224
# Step 88900: Training Loss = 0.0236, Validation Loss = 0.0227
# Step 89250: Training Loss = 0.0235, Validation Loss = 0.0234
# Step 89600: Training Loss = 0.0232, Validation Loss = 0.0227
# Step 89950: Training Loss = 0.0233, Validation Loss = 0.0227
# Step 90300: Training Loss = 0.0232, Validation Loss = 0.0229
# Step 90650: Training Loss = 0.0232, Validation Loss = 0.0226
# Step 91000: Training Loss = 0.0233, Validation Loss = 0.0229
# Epoch 26: Training Loss = 0.0233
# Epoch 26: Validation Loss = 0.0229
# No improvement in validation loss for 3 epoch(s).
# Epoch 27/300
# Step 91350: Training Loss = 0.0233, Validation Loss = 0.0221
# Step 91700: Training Loss = 0.0232, Validation Loss = 0.0229
# Step 92050: Training Loss = 0.0230, Validation Loss = 0.0227
# Step 92400: Training Loss = 0.0230, Validation Loss = 0.0223
# Step 92750: Training Loss = 0.0232, Validation Loss = 0.0237
# Step 93100: Training Loss = 0.0229, Validation Loss = 0.0221
# Step 93450: Training Loss = 0.0230, Validation Loss = 0.0222
# Step 93800: Training Loss = 0.0234, Validation Loss = 0.0228
# Step 94150: Training Loss = 0.0231, Validation Loss = 0.0226
# Step 94500: Training Loss = 0.0231, Validation Loss = 0.0215
# Epoch 27: Training Loss = 0.0231
# Epoch 27: Validation Loss = 0.0215
# New best validation loss: 0.0215. Model saved.
# Epoch 28/300
# Step 94850: Training Loss = 0.0229, Validation Loss = 0.0219
# Step 95200: Training Loss = 0.0232, Validation Loss = 0.0219
# Step 95550: Training Loss = 0.0229, Validation Loss = 0.0218
# Step 95900: Training Loss = 0.0232, Validation Loss = 0.0219
# Step 96250: Training Loss = 0.0228, Validation Loss = 0.0233
# Step 96600: Training Loss = 0.0229, Validation Loss = 0.0224
# Step 96950: Training Loss = 0.0231, Validation Loss = 0.0228
# Step 97300: Training Loss = 0.0234, Validation Loss = 0.0231
# Step 97650: Training Loss = 0.0228, Validation Loss = 0.0221
# Step 98000: Training Loss = 0.0231, Validation Loss = 0.0226
# Epoch 28: Training Loss = 0.0230
# Epoch 28: Validation Loss = 0.0226
# No improvement in validation loss for 1 epoch(s).
# Epoch 29/300
# Step 98350: Training Loss = 0.0227, Validation Loss = 0.0219
# Step 98700: Training Loss = 0.0230, Validation Loss = 0.0223
# Step 99050: Training Loss = 0.0226, Validation Loss = 0.0228
# Step 99400: Training Loss = 0.0229, Validation Loss = 0.0219
# Step 99750: Training Loss = 0.0229, Validation Loss = 0.0220
# Step 100100: Training Loss = 0.0232, Validation Loss = 0.0223
# Step 100450: Training Loss = 0.0233, Validation Loss = 0.0219
# Step 100800: Training Loss = 0.0228, Validation Loss = 0.0217
# Step 101150: Training Loss = 0.0227, Validation Loss = 0.0216
# Step 101500: Training Loss = 0.0228, Validation Loss = 0.0225
# Epoch 29: Training Loss = 0.0229
# Epoch 29: Validation Loss = 0.0225
# No improvement in validation loss for 2 epoch(s).
# Epoch 30/300
# Step 101850: Training Loss = 0.0229, Validation Loss = 0.0224
# Step 102200: Training Loss = 0.0229, Validation Loss = 0.0222
# Step 102550: Training Loss = 0.0230, Validation Loss = 0.0224
# Step 102900: Training Loss = 0.0227, Validation Loss = 0.0222
# Step 103250: Training Loss = 0.0229, Validation Loss = 0.0221
# Step 103600: Training Loss = 0.0230, Validation Loss = 0.0228
# Step 103950: Training Loss = 0.0229, Validation Loss = 0.0228
# Step 104300: Training Loss = 0.0226, Validation Loss = 0.0219
# Step 104650: Training Loss = 0.0228, Validation Loss = 0.0224
# Step 105000: Training Loss = 0.0228, Validation Loss = 0.0220
# Epoch 30: Training Loss = 0.0228
# Epoch 30: Validation Loss = 0.0220
# No improvement in validation loss for 3 epoch(s).
# Epoch 31/300
# Step 105350: Training Loss = 0.0226, Validation Loss = 0.0224
# Step 105700: Training Loss = 0.0227, Validation Loss = 0.0222
# Step 106050: Training Loss = 0.0227, Validation Loss = 0.0220
# Step 106400: Training Loss = 0.0226, Validation Loss = 0.0220
# Step 106750: Training Loss = 0.0229, Validation Loss = 0.0221
# Step 107100: Training Loss = 0.0227, Validation Loss = 0.0220
# Step 107450: Training Loss = 0.0228, Validation Loss = 0.0223
# Step 107800: Training Loss = 0.0229, Validation Loss = 0.0211
# Step 108150: Training Loss = 0.0226, Validation Loss = 0.0217
# Step 108500: Training Loss = 0.0227, Validation Loss = 0.0225
# Epoch 31: Training Loss = 0.0227
# Epoch 31: Validation Loss = 0.0225
# No improvement in validation loss for 4 epoch(s).
# Epoch 32/300
# Step 108850: Training Loss = 0.0225, Validation Loss = 0.0223
# Step 109200: Training Loss = 0.0226, Validation Loss = 0.0220
# Step 109550: Training Loss = 0.0225, Validation Loss = 0.0213
# Step 109900: Training Loss = 0.0227, Validation Loss = 0.0214
# Step 110250: Training Loss = 0.0225, Validation Loss = 0.0220
# Step 110600: Training Loss = 0.0227, Validation Loss = 0.0226
# Step 110950: Training Loss = 0.0225, Validation Loss = 0.0214
# Step 111300: Training Loss = 0.0227, Validation Loss = 0.0221
# Step 111650: Training Loss = 0.0227, Validation Loss = 0.0216
# Step 112000: Training Loss = 0.0224, Validation Loss = 0.0218
# Epoch 32: Training Loss = 0.0226
# Epoch 32: Validation Loss = 0.0218
# No improvement in validation loss for 5 epoch(s).
# Epoch 33/300
# Step 112350: Training Loss = 0.0227, Validation Loss = 0.0224
# Step 112700: Training Loss = 0.0226, Validation Loss = 0.0219
# Step 113050: Training Loss = 0.0224, Validation Loss = 0.0218
# Step 113400: Training Loss = 0.0223, Validation Loss = 0.0236
# Step 113750: Training Loss = 0.0229, Validation Loss = 0.0214
# Step 114100: Training Loss = 0.0221, Validation Loss = 0.0214
# Step 114450: Training Loss = 0.0226, Validation Loss = 0.0217
# Step 114800: Training Loss = 0.0225, Validation Loss = 0.0218
# Step 115150: Training Loss = 0.0225, Validation Loss = 0.0219
# Step 115500: Training Loss = 0.0226, Validation Loss = 0.0217
# Epoch 33: Training Loss = 0.0225
# Epoch 33: Validation Loss = 0.0217
# No improvement in validation loss for 6 epoch(s).
# Epoch 34/300
# Step 115850: Training Loss = 0.0225, Validation Loss = 0.0217
# Step 116200: Training Loss = 0.0220, Validation Loss = 0.0217
# Step 116550: Training Loss = 0.0225, Validation Loss = 0.0215
# Step 116900: Training Loss = 0.0226, Validation Loss = 0.0217
# Step 117250: Training Loss = 0.0223, Validation Loss = 0.0213
# Step 117600: Training Loss = 0.0226, Validation Loss = 0.0215
# Step 117950: Training Loss = 0.0223, Validation Loss = 0.0220
# Step 118300: Training Loss = 0.0226, Validation Loss = 0.0215
# Step 118650: Training Loss = 0.0223, Validation Loss = 0.0218
# Step 119000: Training Loss = 0.0223, Validation Loss = 0.0225
# Epoch 34: Training Loss = 0.0224
# Epoch 34: Validation Loss = 0.0225
# No improvement in validation loss for 7 epoch(s).
# Epoch 35/300
# Step 119350: Training Loss = 0.0220, Validation Loss = 0.0219
# Step 119700: Training Loss = 0.0221, Validation Loss = 0.0216
# Step 120050: Training Loss = 0.0225, Validation Loss = 0.0217
# Step 120400: Training Loss = 0.0227, Validation Loss = 0.0220
# Step 120750: Training Loss = 0.0220, Validation Loss = 0.0213
# Step 121100: Training Loss = 0.0227, Validation Loss = 0.0225
# Step 121450: Training Loss = 0.0223, Validation Loss = 0.0211
# Step 121800: Training Loss = 0.0227, Validation Loss = 0.0209
# Step 122150: Training Loss = 0.0222, Validation Loss = 0.0217
# Step 122500: Training Loss = 0.0222, Validation Loss = 0.0215
# Epoch 35: Training Loss = 0.0223
# Epoch 35: Validation Loss = 0.0215
# New best validation loss: 0.0215. Model saved.
# Epoch 36/300
# Step 122850: Training Loss = 0.0223, Validation Loss = 0.0215
# Step 123200: Training Loss = 0.0223, Validation Loss = 0.0218
# Step 123550: Training Loss = 0.0221, Validation Loss = 0.0220
# Step 123900: Training Loss = 0.0220, Validation Loss = 0.0216
# Step 124250: Training Loss = 0.0220, Validation Loss = 0.0221
# Step 124600: Training Loss = 0.0221, Validation Loss = 0.0218
# Step 124950: Training Loss = 0.0228, Validation Loss = 0.0219
# Step 125300: Training Loss = 0.0223, Validation Loss = 0.0215
# Step 125650: Training Loss = 0.0224, Validation Loss = 0.0219
# Step 126000: Training Loss = 0.0225, Validation Loss = 0.0212
# Epoch 36: Training Loss = 0.0223
# Epoch 36: Validation Loss = 0.0212
# New best validation loss: 0.0212. Model saved.
# Epoch 37/300
# Step 126350: Training Loss = 0.0221, Validation Loss = 0.0216
# Step 126700: Training Loss = 0.0219, Validation Loss = 0.0215
# Step 127050: Training Loss = 0.0220, Validation Loss = 0.0210
# Step 127400: Training Loss = 0.0220, Validation Loss = 0.0219
# Step 127750: Training Loss = 0.0220, Validation Loss = 0.0211
# Step 128100: Training Loss = 0.0221, Validation Loss = 0.0221
# Step 128450: Training Loss = 0.0226, Validation Loss = 0.0217
# Step 128800: Training Loss = 0.0226, Validation Loss = 0.0209
# Step 129150: Training Loss = 0.0223, Validation Loss = 0.0213
# Step 129500: Training Loss = 0.0223, Validation Loss = 0.0211
# Epoch 37: Training Loss = 0.0222
# Epoch 37: Validation Loss = 0.0211
# New best validation loss: 0.0211. Model saved.
# Epoch 38/300
# Step 129850: Training Loss = 0.0217, Validation Loss = 0.0211
# Step 130200: Training Loss = 0.0221, Validation Loss = 0.0212
# Step 130550: Training Loss = 0.0219, Validation Loss = 0.0216
# Step 130900: Training Loss = 0.0222, Validation Loss = 0.0221
# Step 131250: Training Loss = 0.0221, Validation Loss = 0.0211
# Step 131600: Training Loss = 0.0221, Validation Loss = 0.0212
# Step 131950: Training Loss = 0.0222, Validation Loss = 0.0212
# Step 132300: Training Loss = 0.0224, Validation Loss = 0.0208
# Step 132650: Training Loss = 0.0218, Validation Loss = 0.0211
# Step 133000: Training Loss = 0.0223, Validation Loss = 0.0210
# Epoch 38: Training Loss = 0.0221
# Epoch 38: Validation Loss = 0.0210
# New best validation loss: 0.0210. Model saved.
# Epoch 39/300
# Step 133350: Training Loss = 0.0219, Validation Loss = 0.0214
# Step 133700: Training Loss = 0.0220, Validation Loss = 0.0210
# Step 134050: Training Loss = 0.0224, Validation Loss = 0.0214
# Step 134400: Training Loss = 0.0222, Validation Loss = 0.0216
# Step 134750: Training Loss = 0.0218, Validation Loss = 0.0213
# Step 135100: Training Loss = 0.0218, Validation Loss = 0.0211
# Step 135450: Training Loss = 0.0221, Validation Loss = 0.0209
# Step 135800: Training Loss = 0.0222, Validation Loss = 0.0212
# Step 136150: Training Loss = 0.0220, Validation Loss = 0.0211
# Step 136500: Training Loss = 0.0220, Validation Loss = 0.0211
# Epoch 39: Training Loss = 0.0220
# Epoch 39: Validation Loss = 0.0211
# No improvement in validation loss for 1 epoch(s).
# Epoch 40/300
# Step 136850: Training Loss = 0.0218, Validation Loss = 0.0211
# Step 137200: Training Loss = 0.0218, Validation Loss = 0.0215
# Step 137550: Training Loss = 0.0219, Validation Loss = 0.0211
# Step 137900: Training Loss = 0.0221, Validation Loss = 0.0215
# Step 138250: Training Loss = 0.0219, Validation Loss = 0.0213
# Step 138600: Training Loss = 0.0219, Validation Loss = 0.0206
# Step 138950: Training Loss = 0.0217, Validation Loss = 0.0208
# Step 139300: Training Loss = 0.0221, Validation Loss = 0.0218
# Step 139650: Training Loss = 0.0221, Validation Loss = 0.0219
# Step 140000: Training Loss = 0.0220, Validation Loss = 0.0210
# Epoch 40: Training Loss = 0.0219
# Epoch 40: Validation Loss = 0.0210
# No improvement in validation loss for 2 epoch(s).
# Epoch 41/300
# Step 140350: Training Loss = 0.0216, Validation Loss = 0.0216
# Step 140700: Training Loss = 0.0219, Validation Loss = 0.0216
# Step 141050: Training Loss = 0.0219, Validation Loss = 0.0221
# Step 141400: Training Loss = 0.0219, Validation Loss = 0.0214
# Step 141750: Training Loss = 0.0220, Validation Loss = 0.0216
# Step 142100: Training Loss = 0.0220, Validation Loss = 0.0212
# Step 142450: Training Loss = 0.0217, Validation Loss = 0.0208
# Step 142800: Training Loss = 0.0219, Validation Loss = 0.0208
# Step 143150: Training Loss = 0.0220, Validation Loss = 0.0208
# Step 143500: Training Loss = 0.0218, Validation Loss = 0.0214
# Epoch 41: Training Loss = 0.0219
# Epoch 41: Validation Loss = 0.0214
# No improvement in validation loss for 3 epoch(s).
# Epoch 42/300
# Step 143850: Training Loss = 0.0220, Validation Loss = 0.0213
# Step 144200: Training Loss = 0.0217, Validation Loss = 0.0206
# Step 144550: Training Loss = 0.0219, Validation Loss = 0.0207
# Step 144900: Training Loss = 0.0216, Validation Loss = 0.0209
# Step 145250: Training Loss = 0.0217, Validation Loss = 0.0209
# Step 145600: Training Loss = 0.0220, Validation Loss = 0.0206
# Step 145950: Training Loss = 0.0219, Validation Loss = 0.0213
# Step 146300: Training Loss = 0.0217, Validation Loss = 0.0210
# Step 146650: Training Loss = 0.0217, Validation Loss = 0.0210
# Step 147000: Training Loss = 0.0220, Validation Loss = 0.0212
# Epoch 42: Training Loss = 0.0218
# Epoch 42: Validation Loss = 0.0212
# No improvement in validation loss for 4 epoch(s).
# Epoch 43/300
# Step 147350: Training Loss = 0.0217, Validation Loss = 0.0211
# Step 147700: Training Loss = 0.0218, Validation Loss = 0.0211
# Step 148050: Training Loss = 0.0219, Validation Loss = 0.0213
# Step 148400: Training Loss = 0.0217, Validation Loss = 0.0203
# Step 148750: Training Loss = 0.0216, Validation Loss = 0.0213
# Step 149100: Training Loss = 0.0217, Validation Loss = 0.0209
# Step 149450: Training Loss = 0.0216, Validation Loss = 0.0207
# Step 149800: Training Loss = 0.0217, Validation Loss = 0.0215
# Step 150150: Training Loss = 0.0218, Validation Loss = 0.0210
# Step 150500: Training Loss = 0.0221, Validation Loss = 0.0208
# Epoch 43: Training Loss = 0.0218
# Epoch 43: Validation Loss = 0.0208
# New best validation loss: 0.0208. Model saved.
# Epoch 44/300
# Step 150850: Training Loss = 0.0217, Validation Loss = 0.0206
# Step 151200: Training Loss = 0.0216, Validation Loss = 0.0206
# Step 151550: Training Loss = 0.0216, Validation Loss = 0.0210
# Step 151900: Training Loss = 0.0215, Validation Loss = 0.0208
# Step 152250: Training Loss = 0.0220, Validation Loss = 0.0208
# Step 152600: Training Loss = 0.0217, Validation Loss = 0.0214
# Step 152950: Training Loss = 0.0217, Validation Loss = 0.0210
# Step 153300: Training Loss = 0.0218, Validation Loss = 0.0209
# Step 153650: Training Loss = 0.0217, Validation Loss = 0.0206
# Step 154000: Training Loss = 0.0218, Validation Loss = 0.0209
# Epoch 44: Training Loss = 0.0217
# Epoch 44: Validation Loss = 0.0209
# No improvement in validation loss for 1 epoch(s).
# Epoch 45/300
# Step 154350: Training Loss = 0.0217, Validation Loss = 0.0207
# Step 154700: Training Loss = 0.0215, Validation Loss = 0.0209
# Step 155050: Training Loss = 0.0214, Validation Loss = 0.0202
# Step 155400: Training Loss = 0.0218, Validation Loss = 0.0211
# Step 155750: Training Loss = 0.0220, Validation Loss = 0.0204
# Step 156100: Training Loss = 0.0217, Validation Loss = 0.0204
# Step 156450: Training Loss = 0.0216, Validation Loss = 0.0209
# Step 156800: Training Loss = 0.0214, Validation Loss = 0.0203
# Step 157150: Training Loss = 0.0218, Validation Loss = 0.0214
# Step 157500: Training Loss = 0.0215, Validation Loss = 0.0213
# Epoch 45: Training Loss = 0.0216
# Epoch 45: Validation Loss = 0.0213
# No improvement in validation loss for 2 epoch(s).
# Epoch 46/300
# Step 157850: Training Loss = 0.0215, Validation Loss = 0.0207
# Step 158200: Training Loss = 0.0216, Validation Loss = 0.0208
# Step 158550: Training Loss = 0.0213, Validation Loss = 0.0212
# Step 158900: Training Loss = 0.0216, Validation Loss = 0.0211
# Step 159250: Training Loss = 0.0218, Validation Loss = 0.0215
# Step 159600: Training Loss = 0.0217, Validation Loss = 0.0207
# Step 159950: Training Loss = 0.0216, Validation Loss = 0.0209
# Step 160300: Training Loss = 0.0220, Validation Loss = 0.0215
# Step 160650: Training Loss = 0.0214, Validation Loss = 0.0208
# Step 161000: Training Loss = 0.0212, Validation Loss = 0.0214
# Epoch 46: Training Loss = 0.0216
# Epoch 46: Validation Loss = 0.0214
# No improvement in validation loss for 3 epoch(s).
# Epoch 47/300
# Step 161350: Training Loss = 0.0217, Validation Loss = 0.0214
# Step 161700: Training Loss = 0.0217, Validation Loss = 0.0207
# Step 162050: Training Loss = 0.0213, Validation Loss = 0.0208
# Step 162400: Training Loss = 0.0214, Validation Loss = 0.0202
# Step 162750: Training Loss = 0.0216, Validation Loss = 0.0212
# Step 163100: Training Loss = 0.0216, Validation Loss = 0.0220
# Step 163450: Training Loss = 0.0215, Validation Loss = 0.0203
# Step 163800: Training Loss = 0.0217, Validation Loss = 0.0206
# Step 164150: Training Loss = 0.0214, Validation Loss = 0.0205
# Step 164500: Training Loss = 0.0214, Validation Loss = 0.0211
# Epoch 47: Training Loss = 0.0215
# Epoch 47: Validation Loss = 0.0211
# No improvement in validation loss for 4 epoch(s).
# Epoch 48/300
# Step 164850: Training Loss = 0.0215, Validation Loss = 0.0208
# Step 165200: Training Loss = 0.0215, Validation Loss = 0.0209
# Step 165550: Training Loss = 0.0217, Validation Loss = 0.0207
# Step 165900: Training Loss = 0.0212, Validation Loss = 0.0202
# Step 166250: Training Loss = 0.0213, Validation Loss = 0.0207
# Step 166600: Training Loss = 0.0218, Validation Loss = 0.0214
# Step 166950: Training Loss = 0.0216, Validation Loss = 0.0206
# Step 167300: Training Loss = 0.0211, Validation Loss = 0.0208
# Step 167650: Training Loss = 0.0215, Validation Loss = 0.0202
# Step 168000: Training Loss = 0.0215, Validation Loss = 0.0207
# Epoch 48: Training Loss = 0.0215
# Epoch 48: Validation Loss = 0.0207
# New best validation loss: 0.0207. Model saved.
# Epoch 49/300
# Step 168350: Training Loss = 0.0211, Validation Loss = 0.0209
# Step 168700: Training Loss = 0.0214, Validation Loss = 0.0205
# Step 169050: Training Loss = 0.0214, Validation Loss = 0.0207
# Step 169400: Training Loss = 0.0215, Validation Loss = 0.0210
# Step 169750: Training Loss = 0.0214, Validation Loss = 0.0202
# Step 170100: Training Loss = 0.0215, Validation Loss = 0.0201
# Step 170450: Training Loss = 0.0215, Validation Loss = 0.0207
# Step 170800: Training Loss = 0.0217, Validation Loss = 0.0220
# Step 171150: Training Loss = 0.0213, Validation Loss = 0.0207
# Step 171500: Training Loss = 0.0215, Validation Loss = 0.0206
# Epoch 49: Training Loss = 0.0214
# Epoch 49: Validation Loss = 0.0206
# New best validation loss: 0.0206. Model saved.
# Epoch 50/300
# Step 171850: Training Loss = 0.0212, Validation Loss = 0.0209
# Step 172200: Training Loss = 0.0215, Validation Loss = 0.0205
# Step 172550: Training Loss = 0.0216, Validation Loss = 0.0205
# Step 172900: Training Loss = 0.0216, Validation Loss = 0.0206
# Step 173250: Training Loss = 0.0213, Validation Loss = 0.0204
# Step 173600: Training Loss = 0.0212, Validation Loss = 0.0208
# Step 173950: Training Loss = 0.0215, Validation Loss = 0.0207
# Step 174300: Training Loss = 0.0213, Validation Loss = 0.0204
# Step 174650: Training Loss = 0.0212, Validation Loss = 0.0211
# Step 175000: Training Loss = 0.0215, Validation Loss = 0.0205
# Epoch 50: Training Loss = 0.0214
# Epoch 50: Validation Loss = 0.0205
# New best validation loss: 0.0205. Model saved.
# Epoch 51/300
# Step 175350: Training Loss = 0.0212, Validation Loss = 0.0205
# Step 175700: Training Loss = 0.0211, Validation Loss = 0.0207
# Step 176050: Training Loss = 0.0215, Validation Loss = 0.0208
# Step 176400: Training Loss = 0.0212, Validation Loss = 0.0213
# Step 176750: Training Loss = 0.0215, Validation Loss = 0.0210
# Step 177100: Training Loss = 0.0214, Validation Loss = 0.0202
# Step 177450: Training Loss = 0.0214, Validation Loss = 0.0202
# Step 177800: Training Loss = 0.0214, Validation Loss = 0.0213
# Step 178150: Training Loss = 0.0213, Validation Loss = 0.0215
# Step 178500: Training Loss = 0.0214, Validation Loss = 0.0206
# Epoch 51: Training Loss = 0.0213
# Epoch 51: Validation Loss = 0.0206
# No improvement in validation loss for 1 epoch(s).
# Epoch 52/300
# Step 178850: Training Loss = 0.0212, Validation Loss = 0.0206
# Step 179200: Training Loss = 0.0213, Validation Loss = 0.0202
# Step 179550: Training Loss = 0.0209, Validation Loss = 0.0209
# Step 179900: Training Loss = 0.0213, Validation Loss = 0.0206
# Step 180250: Training Loss = 0.0213, Validation Loss = 0.0201
# Step 180600: Training Loss = 0.0214, Validation Loss = 0.0203
# Step 180950: Training Loss = 0.0212, Validation Loss = 0.0205
# Step 181300: Training Loss = 0.0214, Validation Loss = 0.0206
# Step 181650: Training Loss = 0.0210, Validation Loss = 0.0201
# Step 182000: Training Loss = 0.0213, Validation Loss = 0.0209
# Epoch 52: Training Loss = 0.0212
# Epoch 52: Validation Loss = 0.0209
# No improvement in validation loss for 2 epoch(s).
# Epoch 53/300
# Step 182350: Training Loss = 0.0211, Validation Loss = 0.0202
# Step 182700: Training Loss = 0.0212, Validation Loss = 0.0206
# Step 183050: Training Loss = 0.0210, Validation Loss = 0.0198
# Step 183400: Training Loss = 0.0213, Validation Loss = 0.0209
# Step 183750: Training Loss = 0.0213, Validation Loss = 0.0202
# Step 184100: Training Loss = 0.0212, Validation Loss = 0.0212
# Step 184450: Training Loss = 0.0215, Validation Loss = 0.0203
# Step 184800: Training Loss = 0.0212, Validation Loss = 0.0206
# Step 185150: Training Loss = 0.0213, Validation Loss = 0.0207
# Step 185500: Training Loss = 0.0210, Validation Loss = 0.0209
# Epoch 53: Training Loss = 0.0212
# Epoch 53: Validation Loss = 0.0209
# No improvement in validation loss for 3 epoch(s).
# Epoch 54/300
# Step 185850: Training Loss = 0.0210, Validation Loss = 0.0201
# Step 186200: Training Loss = 0.0212, Validation Loss = 0.0221
# Step 186550: Training Loss = 0.0214, Validation Loss = 0.0202
# Step 186900: Training Loss = 0.0212, Validation Loss = 0.0202
# Step 187250: Training Loss = 0.0212, Validation Loss = 0.0205
# Step 187600: Training Loss = 0.0210, Validation Loss = 0.0201
# Step 187950: Training Loss = 0.0213, Validation Loss = 0.0207
# Step 188300: Training Loss = 0.0212, Validation Loss = 0.0214
# Step 188650: Training Loss = 0.0214, Validation Loss = 0.0205
# Step 189000: Training Loss = 0.0212, Validation Loss = 0.0200
# Epoch 54: Training Loss = 0.0212
# Epoch 54: Validation Loss = 0.0200
# New best validation loss: 0.0200. Model saved.
# Epoch 55/300
# Step 189350: Training Loss = 0.0209, Validation Loss = 0.0204
# Step 189700: Training Loss = 0.0213, Validation Loss = 0.0203
# Step 190050: Training Loss = 0.0211, Validation Loss = 0.0201
# Step 190400: Training Loss = 0.0211, Validation Loss = 0.0202
# Step 190750: Training Loss = 0.0210, Validation Loss = 0.0200
# Step 191100: Training Loss = 0.0212, Validation Loss = 0.0205
# Step 191450: Training Loss = 0.0212, Validation Loss = 0.0206
# Step 191800: Training Loss = 0.0212, Validation Loss = 0.0209
# Step 192150: Training Loss = 0.0213, Validation Loss = 0.0209
# Step 192500: Training Loss = 0.0212, Validation Loss = 0.0206
# Epoch 55: Training Loss = 0.0211
# Epoch 55: Validation Loss = 0.0206
# No improvement in validation loss for 1 epoch(s).
# Epoch 56/300
# Step 192850: Training Loss = 0.0210, Validation Loss = 0.0198
# Step 193200: Training Loss = 0.0209, Validation Loss = 0.0202
# Step 193550: Training Loss = 0.0210, Validation Loss = 0.0203
# Step 193900: Training Loss = 0.0209, Validation Loss = 0.0201
# Step 194250: Training Loss = 0.0211, Validation Loss = 0.0200
# Step 194600: Training Loss = 0.0212, Validation Loss = 0.0196
# Step 194950: Training Loss = 0.0211, Validation Loss = 0.0203
# Step 195300: Training Loss = 0.0212, Validation Loss = 0.0202
# Step 195650: Training Loss = 0.0212, Validation Loss = 0.0202
# Step 196000: Training Loss = 0.0214, Validation Loss = 0.0199
# Epoch 56: Training Loss = 0.0211
# Epoch 56: Validation Loss = 0.0199
# New best validation loss: 0.0199. Model saved.
# Epoch 57/300
# Step 196350: Training Loss = 0.0208, Validation Loss = 0.0198
# Step 196700: Training Loss = 0.0210, Validation Loss = 0.0214
# Step 197050: Training Loss = 0.0209, Validation Loss = 0.0209
# Step 197400: Training Loss = 0.0213, Validation Loss = 0.0199
# Step 197750: Training Loss = 0.0210, Validation Loss = 0.0200
# Step 198100: Training Loss = 0.0209, Validation Loss = 0.0202
# Step 198450: Training Loss = 0.0212, Validation Loss = 0.0204
# Step 198800: Training Loss = 0.0210, Validation Loss = 0.0202
# Step 199150: Training Loss = 0.0213, Validation Loss = 0.0201
# Step 199500: Training Loss = 0.0212, Validation Loss = 0.0199
# Epoch 57: Training Loss = 0.0211
# Epoch 57: Validation Loss = 0.0199
# No improvement in validation loss for 1 epoch(s).
# Epoch 58/300
# Step 199850: Training Loss = 0.0209, Validation Loss = 0.0203
# Step 200200: Training Loss = 0.0209, Validation Loss = 0.0207
# Step 200550: Training Loss = 0.0211, Validation Loss = 0.0203
# Step 200900: Training Loss = 0.0211, Validation Loss = 0.0201
# Step 201250: Training Loss = 0.0209, Validation Loss = 0.0199
# Step 201600: Training Loss = 0.0211, Validation Loss = 0.0204
# Step 201950: Training Loss = 0.0210, Validation Loss = 0.0205
# Step 202300: Training Loss = 0.0209, Validation Loss = 0.0208
# Step 202650: Training Loss = 0.0213, Validation Loss = 0.0199
# Step 203000: Training Loss = 0.0209, Validation Loss = 0.0209
# Epoch 58: Training Loss = 0.0210
# Epoch 58: Validation Loss = 0.0209
# No improvement in validation loss for 2 epoch(s).
# Epoch 59/300
# Step 203350: Training Loss = 0.0212, Validation Loss = 0.0208
# Step 203700: Training Loss = 0.0211, Validation Loss = 0.0201
# Step 204050: Training Loss = 0.0208, Validation Loss = 0.0196
# Step 204400: Training Loss = 0.0210, Validation Loss = 0.0199
# Step 204750: Training Loss = 0.0209, Validation Loss = 0.0212
# Step 205100: Training Loss = 0.0208, Validation Loss = 0.0201
# Step 205450: Training Loss = 0.0208, Validation Loss = 0.0199
# Step 205800: Training Loss = 0.0209, Validation Loss = 0.0206
# Step 206150: Training Loss = 0.0212, Validation Loss = 0.0208
# Step 206500: Training Loss = 0.0213, Validation Loss = 0.0206
# Epoch 59: Training Loss = 0.0210
# Epoch 59: Validation Loss = 0.0206
# No improvement in validation loss for 3 epoch(s).
# Epoch 60/300
# Step 206850: Training Loss = 0.0206, Validation Loss = 0.0201
# Step 207200: Training Loss = 0.0205, Validation Loss = 0.0204
# Step 207550: Training Loss = 0.0210, Validation Loss = 0.0203
# Step 207900: Training Loss = 0.0211, Validation Loss = 0.0203
# Step 208250: Training Loss = 0.0211, Validation Loss = 0.0205
# Step 208600: Training Loss = 0.0207, Validation Loss = 0.0209
# Step 208950: Training Loss = 0.0210, Validation Loss = 0.0202
# Step 209300: Training Loss = 0.0211, Validation Loss = 0.0202
# Step 209650: Training Loss = 0.0210, Validation Loss = 0.0201
# Step 210000: Training Loss = 0.0209, Validation Loss = 0.0210
# Epoch 60: Training Loss = 0.0209
# Epoch 60: Validation Loss = 0.0210
# No improvement in validation loss for 4 epoch(s).
# Epoch 61/300
# Step 210350: Training Loss = 0.0206, Validation Loss = 0.0202
# Step 210700: Training Loss = 0.0207, Validation Loss = 0.0199
# Step 211050: Training Loss = 0.0207, Validation Loss = 0.0196
# Step 211400: Training Loss = 0.0212, Validation Loss = 0.0206
# Step 211750: Training Loss = 0.0207, Validation Loss = 0.0203
# Step 212100: Training Loss = 0.0207, Validation Loss = 0.0197
# Step 212450: Training Loss = 0.0209, Validation Loss = 0.0199
# Step 212800: Training Loss = 0.0209, Validation Loss = 0.0213
# Step 213150: Training Loss = 0.0212, Validation Loss = 0.0199
# Step 213500: Training Loss = 0.0212, Validation Loss = 0.0206
# Epoch 61: Training Loss = 0.0209
# Epoch 61: Validation Loss = 0.0206
# No improvement in validation loss for 5 epoch(s).
# Epoch 62/300
# Step 213850: Training Loss = 0.0204, Validation Loss = 0.0202
# Step 214200: Training Loss = 0.0212, Validation Loss = 0.0201
# Step 214550: Training Loss = 0.0210, Validation Loss = 0.0203
# Step 214900: Training Loss = 0.0208, Validation Loss = 0.0202
# Step 215250: Training Loss = 0.0209, Validation Loss = 0.0199
# Step 215600: Training Loss = 0.0210, Validation Loss = 0.0196
# Step 215950: Training Loss = 0.0208, Validation Loss = 0.0200
# Step 216300: Training Loss = 0.0211, Validation Loss = 0.0200
# Step 216650: Training Loss = 0.0208, Validation Loss = 0.0197
# Step 217000: Training Loss = 0.0209, Validation Loss = 0.0196
# Epoch 62: Training Loss = 0.0209
# Epoch 62: Validation Loss = 0.0196
# New best validation loss: 0.0196. Model saved.
# Epoch 63/300
# Step 217350: Training Loss = 0.0208, Validation Loss = 0.0203
# Step 217700: Training Loss = 0.0207, Validation Loss = 0.0201
# Step 218050: Training Loss = 0.0206, Validation Loss = 0.0201
# Step 218400: Training Loss = 0.0207, Validation Loss = 0.0200
# Step 218750: Training Loss = 0.0204, Validation Loss = 0.0198
# Step 219100: Training Loss = 0.0211, Validation Loss = 0.0198
# Step 219450: Training Loss = 0.0210, Validation Loss = 0.0200
# Step 219800: Training Loss = 0.0209, Validation Loss = 0.0204
# Step 220150: Training Loss = 0.0208, Validation Loss = 0.0211
# Step 220500: Training Loss = 0.0210, Validation Loss = 0.0201
# Epoch 63: Training Loss = 0.0208
# Epoch 63: Validation Loss = 0.0201
# No improvement in validation loss for 1 epoch(s).
# Epoch 64/300
# Step 220850: Training Loss = 0.0210, Validation Loss = 0.0200
# Step 221200: Training Loss = 0.0207, Validation Loss = 0.0203
# Step 221550: Training Loss = 0.0212, Validation Loss = 0.0199
# Step 221900: Training Loss = 0.0207, Validation Loss = 0.0203
# Step 222250: Training Loss = 0.0208, Validation Loss = 0.0198
# Step 222600: Training Loss = 0.0207, Validation Loss = 0.0198
# Step 222950: Training Loss = 0.0207, Validation Loss = 0.0201
# Step 223300: Training Loss = 0.0208, Validation Loss = 0.0197
# Step 223650: Training Loss = 0.0207, Validation Loss = 0.0200
# Step 224000: Training Loss = 0.0206, Validation Loss = 0.0196
# Epoch 64: Training Loss = 0.0208
# Epoch 64: Validation Loss = 0.0196
# No improvement in validation loss for 2 epoch(s).
# Epoch 65/300
# Step 224350: Training Loss = 0.0209, Validation Loss = 0.0192
# Step 224700: Training Loss = 0.0210, Validation Loss = 0.0200
# Step 225050: Training Loss = 0.0208, Validation Loss = 0.0196
# Step 225400: Training Loss = 0.0207, Validation Loss = 0.0200
# Step 225750: Training Loss = 0.0208, Validation Loss = 0.0199
# ...
# Step 976850: Training Loss = 0.0176, Validation Loss = 0.0164
# Step 977200: Training Loss = 0.0177, Validation Loss = 0.0166
# Step 977550: Training Loss = 0.0177, Validation Loss = 0.0176
# Step 977900: Training Loss = 0.0172, Validation Loss = 0.0165
# Step 978250: Training Loss = 0.0175, Validation Loss = 0.0166
# Step 978600: Training Loss = 0.0173, Validation Loss = 0.0172
# Step 978950: Training Loss = 0.0178, Validation Loss = 0.0171
# Step 979300: Training Loss = 0.0175, Validation Loss = 0.0177
# Step 979650: Training Loss = 0.0175, Validation Loss = 0.0171
# Step 980000: Training Loss = 0.0174, Validation Loss = 0.0170
# Epoch 280: Training Loss = 0.0175
# Epoch 280: Validation Loss = 0.0170
# No improvement in validation loss for 8 epoch(s).
# Epoch 281/300
# Step 980350: Training Loss = 0.0175, Validation Loss = 0.0166
# Step 980700: Training Loss = 0.0174, Validation Loss = 0.0167
# Step 981050: Training Loss = 0.0174, Validation Loss = 0.0167
# Step 981400: Training Loss = 0.0176, Validation Loss = 0.0166
# Step 981750: Training Loss = 0.0174, Validation Loss = 0.0168
# Step 982100: Training Loss = 0.0177, Validation Loss = 0.0171
# Step 982450: Training Loss = 0.0177, Validation Loss = 0.0172
# Step 982800: Training Loss = 0.0172, Validation Loss = 0.0163
# Step 983150: Training Loss = 0.0176, Validation Loss = 0.0170
# Step 983500: Training Loss = 0.0176, Validation Loss = 0.0167
# Epoch 281: Training Loss = 0.0175
# Epoch 281: Validation Loss = 0.0167
# No improvement in validation loss for 9 epoch(s).
# Epoch 282/300
# Step 983850: Training Loss = 0.0177, Validation Loss = 0.0175
# Step 984200: Training Loss = 0.0176, Validation Loss = 0.0170
# Step 984550: Training Loss = 0.0175, Validation Loss = 0.0173
# Step 984900: Training Loss = 0.0176, Validation Loss = 0.0164
# Step 985250: Training Loss = 0.0175, Validation Loss = 0.0167
# Step 985600: Training Loss = 0.0176, Validation Loss = 0.0167
# Step 985950: Training Loss = 0.0177, Validation Loss = 0.0168
# Step 986300: Training Loss = 0.0175, Validation Loss = 0.0165
# Step 986650: Training Loss = 0.0178, Validation Loss = 0.0173
# Step 987000: Training Loss = 0.0176, Validation Loss = 0.0172
# Epoch 282: Training Loss = 0.0176
# Epoch 282: Validation Loss = 0.0172
# No improvement in validation loss for 10 epoch(s).
# Epoch 283/300
# Step 987350: Training Loss = 0.0173, Validation Loss = 0.0170
# Step 987700: Training Loss = 0.0176, Validation Loss = 0.0165
# Step 988050: Training Loss = 0.0173, Validation Loss = 0.0170
# Step 988400: Training Loss = 0.0174, Validation Loss = 0.0163
# Step 988750: Training Loss = 0.0174, Validation Loss = 0.0166
# Step 989100: Training Loss = 0.0173, Validation Loss = 0.0167
# Step 989450: Training Loss = 0.0179, Validation Loss = 0.0175
# Step 989800: Training Loss = 0.0173, Validation Loss = 0.0172
# Step 990150: Training Loss = 0.0176, Validation Loss = 0.0164
# Step 990500: Training Loss = 0.0175, Validation Loss = 0.0162
# Epoch 283: Training Loss = 0.0175
# Epoch 283: Validation Loss = 0.0162
# New best validation loss: 0.0162. Model saved.
# Epoch 284/300
# Step 990850: Training Loss = 0.0175, Validation Loss = 0.0165
# Step 991200: Training Loss = 0.0176, Validation Loss = 0.0164
# Step 991550: Training Loss = 0.0176, Validation Loss = 0.0171
# Step 991900: Training Loss = 0.0176, Validation Loss = 0.0165
# Step 992250: Training Loss = 0.0174, Validation Loss = 0.0166
# Step 992600: Training Loss = 0.0173, Validation Loss = 0.0166
# Step 992950: Training Loss = 0.0178, Validation Loss = 0.0176
# Step 993300: Training Loss = 0.0173, Validation Loss = 0.0162
# Step 993650: Training Loss = 0.0174, Validation Loss = 0.0169
# Step 994000: Training Loss = 0.0176, Validation Loss = 0.0170
# Epoch 284: Training Loss = 0.0175
# Epoch 284: Validation Loss = 0.0170
# No improvement in validation loss for 1 epoch(s).
# Epoch 285/300
# Step 994350: Training Loss = 0.0174, Validation Loss = 0.0164
# Step 994700: Training Loss = 0.0173, Validation Loss = 0.0171
# Step 995050: Training Loss = 0.0177, Validation Loss = 0.0169
# Step 995400: Training Loss = 0.0175, Validation Loss = 0.0172
# Step 995750: Training Loss = 0.0173, Validation Loss = 0.0169
# Step 996100: Training Loss = 0.0177, Validation Loss = 0.0163
# Step 996450: Training Loss = 0.0175, Validation Loss = 0.0172
# Step 996800: Training Loss = 0.0175, Validation Loss = 0.0165
# Step 997150: Training Loss = 0.0174, Validation Loss = 0.0171
# Step 997500: Training Loss = 0.0174, Validation Loss = 0.0170
# Epoch 285: Training Loss = 0.0175
# Epoch 285: Validation Loss = 0.0170
# No improvement in validation loss for 2 epoch(s).
# Epoch 286/300
# Step 997850: Training Loss = 0.0173, Validation Loss = 0.0166
# Step 998200: Training Loss = 0.0175, Validation Loss = 0.0169
# Step 998550: Training Loss = 0.0176, Validation Loss = 0.0171
# Step 998900: Training Loss = 0.0175, Validation Loss = 0.0170
# Step 999250: Training Loss = 0.0175, Validation Loss = 0.0167
# Step 999600: Training Loss = 0.0175, Validation Loss = 0.0166
# Step 999950: Training Loss = 0.0173, Validation Loss = 0.0169
# Step 1000300: Training Loss = 0.0175, Validation Loss = 0.0172
# Step 1000650: Training Loss = 0.0178, Validation Loss = 0.0166
# Step 1001000: Training Loss = 0.0176, Validation Loss = 0.0166
# Epoch 286: Training Loss = 0.0175
# Epoch 286: Validation Loss = 0.0166
# No improvement in validation loss for 3 epoch(s).
# Epoch 287/300
# Step 1001350: Training Loss = 0.0174, Validation Loss = 0.0171
# Step 1001700: Training Loss = 0.0176, Validation Loss = 0.0169
# Step 1002050: Training Loss = 0.0175, Validation Loss = 0.0167
# Step 1002400: Training Loss = 0.0172, Validation Loss = 0.0178
# Step 1002750: Training Loss = 0.0175, Validation Loss = 0.0162
# Step 1003100: Training Loss = 0.0174, Validation Loss = 0.0167
# Step 1003450: Training Loss = 0.0175, Validation Loss = 0.0167
# Step 1003800: Training Loss = 0.0175, Validation Loss = 0.0172
# Step 1004150: Training Loss = 0.0175, Validation Loss = 0.0167
# Step 1004500: Training Loss = 0.0176, Validation Loss = 0.0172
# Epoch 287: Training Loss = 0.0175
# Epoch 287: Validation Loss = 0.0172
# No improvement in validation loss for 4 epoch(s).
# Epoch 288/300
# Step 1004850: Training Loss = 0.0173, Validation Loss = 0.0165
# Step 1005200: Training Loss = 0.0177, Validation Loss = 0.0174
# Step 1005550: Training Loss = 0.0172, Validation Loss = 0.0174
# Step 1005900: Training Loss = 0.0174, Validation Loss = 0.0171
# Step 1006250: Training Loss = 0.0176, Validation Loss = 0.0169
# Step 1006600: Training Loss = 0.0176, Validation Loss = 0.0174
# Step 1006950: Training Loss = 0.0177, Validation Loss = 0.0171
# Step 1007300: Training Loss = 0.0174, Validation Loss = 0.0170
# Step 1007650: Training Loss = 0.0175, Validation Loss = 0.0171
# Step 1008000: Training Loss = 0.0174, Validation Loss = 0.0174
# Epoch 288: Training Loss = 0.0175
# Epoch 288: Validation Loss = 0.0174
# No improvement in validation loss for 5 epoch(s).
# Epoch 289/300
# Step 1008350: Training Loss = 0.0173, Validation Loss = 0.0176
# Step 1008700: Training Loss = 0.0177, Validation Loss = 0.0172
# Step 1009050: Training Loss = 0.0175, Validation Loss = 0.0172
# Step 1009400: Training Loss = 0.0173, Validation Loss = 0.0163
# Step 1009750: Training Loss = 0.0176, Validation Loss = 0.0171
# Step 1010100: Training Loss = 0.0174, Validation Loss = 0.0163
# Step 1010450: Training Loss = 0.0175, Validation Loss = 0.0166
# Step 1010800: Training Loss = 0.0174, Validation Loss = 0.0164
# Step 1011150: Training Loss = 0.0171, Validation Loss = 0.0169
# Step 1011500: Training Loss = 0.0177, Validation Loss = 0.0175
# Epoch 289: Training Loss = 0.0175
# Epoch 289: Validation Loss = 0.0175
# No improvement in validation loss for 6 epoch(s).
# Epoch 290/300
# Step 1011850: Training Loss = 0.0175, Validation Loss = 0.0166
# Step 1012200: Training Loss = 0.0172, Validation Loss = 0.0165
# Step 1012550: Training Loss = 0.0176, Validation Loss = 0.0165
# Step 1012900: Training Loss = 0.0174, Validation Loss = 0.0161
# Step 1013250: Training Loss = 0.0174, Validation Loss = 0.0165
# Step 1013600: Training Loss = 0.0175, Validation Loss = 0.0167
# Step 1013950: Training Loss = 0.0177, Validation Loss = 0.0168
# Step 1014300: Training Loss = 0.0174, Validation Loss = 0.0165
# Step 1014650: Training Loss = 0.0176, Validation Loss = 0.0168
# Step 1015000: Training Loss = 0.0172, Validation Loss = 0.0164
# Epoch 290: Training Loss = 0.0175
# Epoch 290: Validation Loss = 0.0164
# No improvement in validation loss for 7 epoch(s).
# Epoch 291/300
# Step 1015350: Training Loss = 0.0176, Validation Loss = 0.0168
# Step 1015700: Training Loss = 0.0173, Validation Loss = 0.0166
# Step 1016050: Training Loss = 0.0174, Validation Loss = 0.0169
# Step 1016400: Training Loss = 0.0174, Validation Loss = 0.0164
# Step 1016750: Training Loss = 0.0173, Validation Loss = 0.0165
# Step 1017100: Training Loss = 0.0176, Validation Loss = 0.0174
# Step 1017450: Training Loss = 0.0172, Validation Loss = 0.0167
# Step 1017800: Training Loss = 0.0176, Validation Loss = 0.0166
# Step 1018150: Training Loss = 0.0174, Validation Loss = 0.0162
# Step 1018500: Training Loss = 0.0176, Validation Loss = 0.0168
# Epoch 291: Training Loss = 0.0174
# Epoch 291: Validation Loss = 0.0168
# No improvement in validation loss for 8 epoch(s).
# Epoch 292/300
# Step 1018850: Training Loss = 0.0175, Validation Loss = 0.0167
# Step 1019200: Training Loss = 0.0173, Validation Loss = 0.0168
# Step 1019550: Training Loss = 0.0174, Validation Loss = 0.0175
# Step 1019900: Training Loss = 0.0173, Validation Loss = 0.0169
# Step 1020250: Training Loss = 0.0177, Validation Loss = 0.0169
# Step 1020600: Training Loss = 0.0176, Validation Loss = 0.0166
# Step 1020950: Training Loss = 0.0174, Validation Loss = 0.0169
# Step 1021300: Training Loss = 0.0177, Validation Loss = 0.0173
# Step 1021650: Training Loss = 0.0175, Validation Loss = 0.0168
# Step 1022000: Training Loss = 0.0173, Validation Loss = 0.0166
# Epoch 292: Training Loss = 0.0175
# Epoch 292: Validation Loss = 0.0166
# No improvement in validation loss for 9 epoch(s).
# Epoch 293/300
# Step 1022350: Training Loss = 0.0175, Validation Loss = 0.0179
# Step 1022700: Training Loss = 0.0177, Validation Loss = 0.0165
# Step 1023050: Training Loss = 0.0176, Validation Loss = 0.0172
# Step 1023400: Training Loss = 0.0173, Validation Loss = 0.0172
# Step 1023750: Training Loss = 0.0172, Validation Loss = 0.0169
# Step 1024100: Training Loss = 0.0176, Validation Loss = 0.0173
# Step 1024450: Training Loss = 0.0173, Validation Loss = 0.0164
# Step 1024800: Training Loss = 0.0173, Validation Loss = 0.0167
# Step 1025150: Training Loss = 0.0176, Validation Loss = 0.0172
# Step 1025500: Training Loss = 0.0176, Validation Loss = 0.0166
# Epoch 293: Training Loss = 0.0175
# Epoch 293: Validation Loss = 0.0166
# No improvement in validation loss for 10 epoch(s).
# Epoch 294/300
# Step 1025850: Training Loss = 0.0173, Validation Loss = 0.0170
# Step 1026200: Training Loss = 0.0176, Validation Loss = 0.0172
# Step 1026550: Training Loss = 0.0173, Validation Loss = 0.0168
# Step 1026900: Training Loss = 0.0175, Validation Loss = 0.0168
# Step 1027250: Training Loss = 0.0174, Validation Loss = 0.0178
# Step 1027600: Training Loss = 0.0175, Validation Loss = 0.0169
# Step 1027950: Training Loss = 0.0174, Validation Loss = 0.0165
# Step 1028300: Training Loss = 0.0174, Validation Loss = 0.0173
# Step 1028650: Training Loss = 0.0176, Validation Loss = 0.0170
# Step 1029000: Training Loss = 0.0174, Validation Loss = 0.0170
# Epoch 294: Training Loss = 0.0174
# Epoch 294: Validation Loss = 0.0170
# No improvement in validation loss for 11 epoch(s).
# Epoch 295/300
# Step 1029350: Training Loss = 0.0173, Validation Loss = 0.0165
# Step 1029700: Training Loss = 0.0173, Validation Loss = 0.0163
# Step 1030050: Training Loss = 0.0173, Validation Loss = 0.0162
# Step 1030400: Training Loss = 0.0176, Validation Loss = 0.0168
# Step 1030750: Training Loss = 0.0176, Validation Loss = 0.0167
# Step 1031100: Training Loss = 0.0173, Validation Loss = 0.0173
# Step 1031450: Training Loss = 0.0176, Validation Loss = 0.0164
# Step 1031800: Training Loss = 0.0177, Validation Loss = 0.0169
# Step 1032150: Training Loss = 0.0174, Validation Loss = 0.0174
# Step 1032500: Training Loss = 0.0175, Validation Loss = 0.0167
# Epoch 295: Training Loss = 0.0175
# Epoch 295: Validation Loss = 0.0167
# No improvement in validation loss for 12 epoch(s).
# Epoch 296/300
# Step 1032850: Training Loss = 0.0173, Validation Loss = 0.0163
# Step 1033200: Training Loss = 0.0173, Validation Loss = 0.0165
# Step 1033550: Training Loss = 0.0175, Validation Loss = 0.0175
# Step 1033900: Training Loss = 0.0174, Validation Loss = 0.0164
# Step 1034250: Training Loss = 0.0177, Validation Loss = 0.0167
# Step 1034600: Training Loss = 0.0173, Validation Loss = 0.0169
# Step 1034950: Training Loss = 0.0174, Validation Loss = 0.0171
# Step 1035300: Training Loss = 0.0174, Validation Loss = 0.0165
# Step 1035650: Training Loss = 0.0173, Validation Loss = 0.0170
# Step 1036000: Training Loss = 0.0174, Validation Loss = 0.0169
# Epoch 296: Training Loss = 0.0174
# Epoch 296: Validation Loss = 0.0169
# No improvement in validation loss for 13 epoch(s).
# Epoch 297/300
# Step 1036350: Training Loss = 0.0174, Validation Loss = 0.0171
# Step 1036700: Training Loss = 0.0176, Validation Loss = 0.0170
# Step 1037050: Training Loss = 0.0175, Validation Loss = 0.0163
# Step 1037400: Training Loss = 0.0172, Validation Loss = 0.0166
# Step 1037750: Training Loss = 0.0173, Validation Loss = 0.0165
# Step 1038100: Training Loss = 0.0175, Validation Loss = 0.0163
# Step 1038450: Training Loss = 0.0172, Validation Loss = 0.0172
# Step 1038800: Training Loss = 0.0175, Validation Loss = 0.0167
# Step 1039150: Training Loss = 0.0175, Validation Loss = 0.0164
# Step 1039500: Training Loss = 0.0175, Validation Loss = 0.0166
# Epoch 297: Training Loss = 0.0174
# Epoch 297: Validation Loss = 0.0166
# No improvement in validation loss for 14 epoch(s).
# Epoch 298/300
# Step 1039850: Training Loss = 0.0174, Validation Loss = 0.0166
# Step 1040200: Training Loss = 0.0172, Validation Loss = 0.0164
# Step 1040550: Training Loss = 0.0173, Validation Loss = 0.0164
# Step 1040900: Training Loss = 0.0175, Validation Loss = 0.0171
# Step 1041250: Training Loss = 0.0174, Validation Loss = 0.0173
# Step 1041600: Training Loss = 0.0175, Validation Loss = 0.0168
# Step 1041950: Training Loss = 0.0173, Validation Loss = 0.0166
# Step 1042300: Training Loss = 0.0173, Validation Loss = 0.0171
# Step 1042650: Training Loss = 0.0175, Validation Loss = 0.0172
# Step 1043000: Training Loss = 0.0175, Validation Loss = 0.0170
# Epoch 298: Training Loss = 0.0174
# Epoch 298: Validation Loss = 0.0170
# No improvement in validation loss for 15 epoch(s).
# Epoch 299/300
# Step 1043350: Training Loss = 0.0172, Validation Loss = 0.0169
# Step 1043700: Training Loss = 0.0173, Validation Loss = 0.0169
# Step 1044050: Training Loss = 0.0175, Validation Loss = 0.0165
# Step 1044400: Training Loss = 0.0174, Validation Loss = 0.0164
# Step 1044750: Training Loss = 0.0175, Validation Loss = 0.0164
# Step 1045100: Training Loss = 0.0175, Validation Loss = 0.0171
# Step 1045450: Training Loss = 0.0175, Validation Loss = 0.0163
# Step 1045800: Training Loss = 0.0177, Validation Loss = 0.0170
# Step 1046150: Training Loss = 0.0174, Validation Loss = 0.0164
# Step 1046500: Training Loss = 0.0174, Validation Loss = 0.0164
# Epoch 299: Training Loss = 0.0174
# Epoch 299: Validation Loss = 0.0164
# No improvement in validation loss for 16 epoch(s).
# Epoch 300/300
# Step 1046850: Training Loss = 0.0174, Validation Loss = 0.0171
# Step 1047200: Training Loss = 0.0175, Validation Loss = 0.0165
# Step 1047550: Training Loss = 0.0175, Validation Loss = 0.0165
# Step 1047900: Training Loss = 0.0174, Validation Loss = 0.0161
# Step 1048250: Training Loss = 0.0173, Validation Loss = 0.0166
# Step 1048600: Training Loss = 0.0175, Validation Loss = 0.0165
# Step 1048950: Training Loss = 0.0173, Validation Loss = 0.0167
# Step 1049300: Training Loss = 0.0175, Validation Loss = 0.0164
# Step 1049650: Training Loss = 0.0174, Validation Loss = 0.0171
# Step 1050000: Training Loss = 0.0173, Validation Loss = 0.0172
# Epoch 300: Training Loss = 0.0174
# Epoch 300: Validation Loss = 0.0172
# No improvement in validation loss for 17 epoch(s).
# Training complete!

# %%
plt.figure(figsize=(8, 6))
plt.plot([i * validation_every_steps for i in range(len(train_losses))], train_losses, label="Training loss")
plt.plot([i * validation_every_steps for i in range(len(val_losses))], val_losses, label="Validation loss")
plt.xlabel("Training Steps")
plt.ylabel("Loss")
plt.title("Training and Validation Loss, Mandatory Features")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6))
epochs = range(1, num_epochs + 1)
plt.plot(epochs, epoch_train_losses, label="Training loss")
plt.plot(epochs, epoch_val_losses, label="Validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss per Epoch")
plt.legend()
plt.grid()
plt.show()

# %%
# Model in evaluation mode
model.load_state_dict(torch.load('best_model.pth'))
model.eval()

actual_values = []
predicted_values = []

with torch.no_grad():
    for x_batch, y_batch in test_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        x_batch = x_batch.unsqueeze(2)
        outputs = model(x_batch)
        actual_values.append(y_batch.cpu().numpy())
        predicted_values.append(outputs.cpu().numpy())

actual_values = np.concatenate(actual_values, axis=0)
predicted_values = np.concatenate(predicted_values, axis=0)

# Invert the scaling to get original values
# Separate scalers for X and y
actual_values_inv = scaler_y.inverse_transform(actual_values)
predicted_values_inv = scaler_y.inverse_transform(predicted_values)

target_names = targets  # ['Mz1', 'Mz2', 'Mz3']

num_samples_to_plot = 200
time_steps = np.arange(num_samples_to_plot)
plt.figure(figsize=(15, 10))

for i, target in enumerate(target_names):
    plt.subplot(len(target_names), 1, i+1)
    plt.plot(time_steps, actual_values_inv[:num_samples_to_plot, i], label='Actual', color='blue')
    plt.plot(time_steps, predicted_values_inv[:num_samples_to_plot, i], label='Predicted', color='red', alpha=0.7)
    plt.title(f'Actual vs. Predicted for {target}')
    plt.xlabel('Sample')
    plt.ylabel(target)
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ropet\AppData\Local\Temp\ipykernel_25772\4173142168.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate the metrics
mae = mean_absolute_error(actual_values_inv, predicted_values_inv)
mse = mean_squared_error(actual_values_inv, predicted_values_inv)
rmse = np.sqrt(mse)
r2 = r2_score(actual_values_inv, predicted_values_inv)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# Evaluation Metrics:
# Mean Absolute Error (MAE): 3.9212
# Mean Squared Error (MSE): 25.2734
# Root Mean Squared Error (RMSE): 5.0273
# R-squared (R²): 0.9838
